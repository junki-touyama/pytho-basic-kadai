# %%
humans = [a, b, c]
class Human:

  def __init__(self, name, age):
    self.name = name
    self.age = age

  def check_adult(self):
    if self.age >= 20:
      print(f"{self.name}は、大人です。")
    else:
      print(f"{self.name}は、まだ子どもです。")
    for num in humans:
      print(humans.check_adult())

a = Human("當山純輝", 32)
b = Human("當山姫子", 32)
c = Human("當山もも", 5)
